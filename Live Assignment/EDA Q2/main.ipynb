# %%
import pandas as pd

# %%
df = pd.read_csv('election2024.csv')
len(df)
# Out:
# 1600

# %%
df
# Out:
#                     id     sex  age federal_district  \
# 0     07169ed8148ce047    male   18  north caucasian
# 1     0716a4f3354cecdd    male   23  north caucasian
# 2     0716889b304ce79c    male   20            volga
# 3     07168e28b5cce563    male   22     northwestern
# 4     0716a563914ce549    male   21         southern
# ...                ...     ...  ...              ...
# 1595  0716b23c2c0cee3a    male   61          central
# 1596  07168254d14ceb55  female   80            volga
# 1597  071690f34d4ce164  female   76     northwestern
# 1598  0716bfa9c48ce79a  female   74          central
# 1599  07168088318cef88  female   76             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# ...

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# id
# 07169ed8148ce047    1
# 0716a8f7a98ceab4    1
# 0716968485ccea72    1
# 07167fa9264ceb65    1
# 07166778618ce822    1
#                    ..
# 0716afc0a28cea87    1
# 07168fbd9d4ce53f    1
# 07167bd65a0ce094    1
# 07168f3957cce462    1
# 07168088318cef88    1
# Name: count, Length: 1600, dtype: int64
# sex
# female    843
# male      757
# Name: count, dtype: int64
# age
# 40    46
# 37    46
# 45    45
# 38    44
# 39    39
#       ..
# 86     4
# 85     4
# 87     3
# 81     3
# 90     1
# Name: count, Length: 71, dtype: int64
# federal_district
# central            425
# volga              324
# siberian           188
# southern           182
# northwestern       151
# ural               134
# north caucasian    107
# far eastern         89
# Name: count, dtype: int64
# type_of_city
# city with population of 100-500k                391
# village                                         366
# city with population of 1 million and higher    307
# ...

# %%
df.isnull().sum()
# Out:
# id                       0
# sex                      0
# age                      0
# federal_district         0
# type_of_city             0
# knows_election_date      0
# will_vote                0
# candidate                0
# television_usage         0
# internet_usage           0
# education                0
# income                   0
# employment               0
# job_type               908
# company_type           721
# weight1                  0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# id                     0
# sex                    0
# age                    0
# federal_district       0
# type_of_city           0
# knows_election_date    0
# will_vote              0
# candidate              0
# television_usage       0
# internet_usage         0
# education              0
# income                 0
# employment             0
# job_type               0
# company_type           0
# weight1                0
# dtype: int64

# %%
len(df)
# Out:
# 670

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.hist(df['television_usage'])
plt.xticks(rotation=90)  
plt.title("television_usage")
# Out:
# Text(0.5, 1.0, 'television_usage')

# %%
plt.hist(df['type_of_city'])
plt.xticks(rotation=90)  
plt.title("type_of_city")
# Out:
# Text(0.5, 1.0, 'type_of_city')

# %%
plt.hist(df['federal_district'])
plt.xticks(rotation=90)  
plt.title("federal_district")
# Out:
# Text(0.5, 1.0, 'federal_district')

# %%
plt.hist(df['company_type'])
plt.xticks(rotation=90)  
plt.title("company_type")
# Out:
# Text(0.5, 1.0, 'company_type')

# %%
plt.boxplot(df['age'], patch_artist=True, notch=True, vert=True) 
plt.xlabel("Age Set")
plt.ylabel("Value")
plt.title("AGE BOXPLOT")
# Out:
# Text(0.5, 1.0, 'AGE BOXPLOT')
