# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# ...

# %%
df.count()
# Out:
# GENDER                   3000
# AGE                      3000
# SMOKING                  3000
# YELLOW_FINGERS           3000
# ANXIETY                  3000
# PEER_PRESSURE            3000
# CHRONIC_DISEASE          3000
# FATIGUE                  3000
# ALLERGY                  3000
# WHEEZING                 3000
# ALCOHOL_CONSUMING        3000
# COUGHING                 3000
# SHORTNESS_OF_BREATH      3000
# SWALLOWING_DIFFICULTY    3000
# CHEST_PAIN               3000
# LUNG_CANCER              3000
# dtype: int64

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
for i in df.columns[3:15]:
  print(i)
  pp1 = df[i].value_counts().get(1,0)
  pp2 = df[i].value_counts().get(2,0)
  print(f"1s: {pp1} and 2s: {pp2}")
# Out:
# YELLOW_FINGERS
# 1s: 1458 and 2s: 1542
# ANXIETY
# 1s: 1518 and 2s: 1482
# PEER_PRESSURE
# 1s: 1503 and 2s: 1497
# CHRONIC_DISEASE
# 1s: 1471 and 2s: 1529
# FATIGUE
# 1s: 1531 and 2s: 1469
# ALLERGY
# 1s: 1480 and 2s: 1520
# WHEEZING
# 1s: 1508 and 2s: 1492
# ALCOHOL_CONSUMING
# 1s: 1526 and 2s: 1474
# COUGHING
# 1s: 1468 and 2s: 1532
# SHORTNESS_OF_BREATH
# 1s: 1536 and 2s: 1464
# SWALLOWING_DIFFICULTY
# 1s: 1531 and 2s: 1469
# CHEST_PAIN
# 1s: 1504 and 2s: 1496

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df = df.drop_duplicates()

# %%
len(df)
# Out:
# 2998

# %%
df['AGE'].describe()
# Out:
# count    2998.000000
# mean       55.171448
# std        14.728302
# min        30.000000
# 25%        42.000000
# 50%        55.000000
# 75%        68.000000
# max        80.000000
# Name: AGE, dtype: float64

# %%
male = (df['GENDER'] != 'M').sum()
female = (df['GENDER']=='M').sum()
print(f"Males:{male} and females:{female}")
# Out:
# Males:1486 and females:1512

# %%
plt.figure(figsize=(20,15))
for i,column in enumerate(df.columns):
    plt.subplot(5,5,i+1)
    plt.hist(df[column])
    plt.title(f'{column} Distribution')
plt.tight_layout()

# %%
# Calculate skewness
skewness = df['AGE'].skew()

# Create a distribution plot with a rug plot to show skewness
sns.displot(df['AGE'], kde=True, rug=True)

# Add a title and label for skewness
plt.title(f"Distribution of AGE")
plt.xlabel('col1 values')
plt.ylabel('Density')
plt.grid(True)

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)
# Out:
# (array([20., 30., 40., 50., 60., 70., 80., 90.]),
#  [Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60'),
#   Text(70.0, 0, '70'),
#   Text(80.0, 0, '80'),
#   Text(90.0, 0, '90')])

# %%
df['AGE'].plot(kind='box')

# Add a title and labels (optional)
plt.title('Box Plot of col1')
plt.xlabel('col1')
plt.ylabel('Value')
plt.grid(True)

plt.show()
